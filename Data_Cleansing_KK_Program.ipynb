# %%
import time

start_time = time.time()

# %%
# !pip install openpyxl
import openpyxl
import zipfile
import pandas as pd
import re
from datetime import datetime
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
# Load full_data spreadsheet
workbook = openpyxl.load_workbook('full_data.xlsx')
sheet_name = workbook.sheetnames


df_full = pd.DataFrame()
for sheet in sheet_name:
    try:
        df = pd.read_excel('full_data.xlsx', sheet_name=sheet, dtype={'KK_NO_GROSS':object,'KK_NO':object, 'NIK_GROSS':object,'NIK':object})
        df_full = pd.concat([df_full, df], ignore_index=True)
    except FileNotFoundError:
        print(f"File not found: full_data.xlsx. Please check the file path.")
        break
    except zipfile.BadZipFile:
        print(f"Invalid Excel file: full_data.xlsx. The file might be corrupted or not a valid Excel file.")
        break
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        break

df = df_full
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1452 is marked as a date but the serial value 6596868 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1600 is marked as a date but the serial value 6614368 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1827 is marked as a date but the serial value 6614368 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M5174 is marked as a date but the serial value 14041000 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M316 is marked as a date but the serial value 6613098 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2700 is marked as a date but the serial value 6619613 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2446 is marked as a date but the serial value 7020361 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3581 is marked as a date but the serial value 352703300380002 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3626 is marked as a date but the serial value 24052003 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3698 is marked as a date but the serial value 15052019 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3835 is marked as a date but the serial value 25112121 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3836 is marked as a date but the serial value 25112121 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3917 is marked as a date but the serial value 6520259 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M4347 is marked as a date but the serial value 14033014 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1027 is marked as a date but the serial value 6692499 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2396 is marked as a date but the serial value 6505462 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3315 is marked as a date but the serial value 15474871 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3316 is marked as a date but the serial value 15474871 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3628 is marked as a date but the serial value 21414583 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M4166 is marked as a date but the serial value 15151963 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1700 is marked as a date but the serial value 6655991 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1452 is marked as a date but the serial value 6596868 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1600 is marked as a date but the serial value 6614368 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1827 is marked as a date but the serial value 6614368 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M5174 is marked as a date but the serial value 14041000 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M316 is marked as a date but the serial value 6613098 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2700 is marked as a date but the serial value 6619613 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2446 is marked as a date but the serial value 7020361 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3581 is marked as a date but the serial value 352703300380002 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3626 is marked as a date but the serial value 24052003 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3698 is marked as a date but the serial value 15052019 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3835 is marked as a date but the serial value 25112121 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3836 is marked as a date but the serial value 25112121 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3917 is marked as a date but the serial value 6520259 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M4347 is marked as a date but the serial value 14033014 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1027 is marked as a date but the serial value 6692499 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M2396 is marked as a date but the serial value 6505462 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3315 is marked as a date but the serial value 15474871 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3316 is marked as a date but the serial value 15474871 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M3628 is marked as a date but the serial value 21414583 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M4166 is marked as a date but the serial value 15151963 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell M1700 is marked as a date but the serial value 6655991 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
df_kota_indonesia = pd.read_csv('list_kota.txt', delimiter=',')
df_kota_indonesia['CITY_DESC'] = df_kota_indonesia['CITY_DESC'].str.replace('Kota ', '').str.replace('Kabupaten ', '').str.replace('Kab ', '')
df_kota_indonesia['CITY_DESC'] = df_kota_indonesia['CITY_DESC'].str.upper()
kota_indonesia = df_kota_indonesia['CITY_DESC'].tolist()

# %%
new_kota = [
'ACEH BARAT',
'ACEH BESAR',
'ACEH TAMIANG',
'ACEH TIMUR',
'ACEH',
'AIR DINGIN ',
'AIR MOLEK',
'AIR NANINGAN',
'AKEDAGA',
'AMBARAWA',
'AMBON',
'AMPENAN',
'ASAHAN',
'BAA ROTE',
'BAGOR',
'BALAM',
'BALI',
'BALIGE',
'BALIKPAPAN',
'BALUNGAN',
'BANDA ACEH',
'BANDAR BETSY',
'BANDAR DALAM',
'BANDAR LAMPUNG',
'BANDUNG BARAT',
'BANDUNG',
'BANGGAI',
'BANGKA BARAT',
'BANGKA',
'BANGKALAN',
'BANJAR',
'BANJARMASIN',
'BANJARNEGARA',
'BANJARSARI',
'BANTAL',
'BANTARWARU',
'BANTEN',
'BANTUL',
'BANYUASIN',
'BANYUMAS',
'BANYUWANGI',
'BARITO KUALA',
'BATAM',
'BATANG HARI',
'BATANG',
'BATOLA',
'BATU KAMBING',
'BATURAJA',
'BATURSARI',
'BAYANG',
'BAYUNG LENCIR INDAH',
'BEKASI',
'BELAWAN ',
'BELITANG',
'BELOPA',
'BENGKALIS',
'BENGKULU UTARA',
'BENGKULU',
'BERAU',
'BERGAS',
'BERINGIN JAYA',
'BIAK',
'BIMA',
'BINJAI',
'BLITAR',
'BLORA',
'BOBOTSARI',
'BOGOR',
'BOJONEGORO',
'BONDOWOSO',
'BOYOLALI',
'BREBES',
'BUAYAN',
'BUKABU',
'BUKIT TINGGI',
'BUMIAYU',
'BUNTU MAULI',
'CAHAYA NEGERI',
'CAWAS',
'CENGAL',
'CEPU',
'CIAMIS',
'CIANJUR',
'CIKARANG',
'CILACAP',
'CILEGON',
'CIMAHI',
'CIMANGGU',
'CIPUTAT',
'CIRACAP',
'CIREBON',
'CISAMPANG',
'DELI SERDANG',
'DEMAK',
'DENPASAR',
'DEPOK',
'DONGGALA',
'DUKUH',
'DUMAI',
'DURI',
'ENDE',
'GADING',
'GARUT',
'GEGARANG',
'GEMARANG',
'GENDING',
'GETASAN',
'GIRIWINANGUN',
'GOMBONG',
'GONDANG',
'GORONTALO',
'GRESIK',
'GROBOGAN',
'GUNUNG KIDUL',
'GUNUNGKIDUL',
'GUNUNGPATI',
'GUNUNGSITOLI',
'HILIMBOWO',
'HILIWAEBU',
'HILIZOROILAWA',
'HORISAN RANGGITGIT',
'HUTAMULA',
'INDRAGIRI HILIR',
'INDRAGIRI HULU',
'INDRAGIRIHULU',
'INDRAMAYU',
'INDRAPURA',
'JABUNG',
'JAKARTA BARAT',
'JAKARTA PUSAT',
'JAKARTA SELATAN',
'JAKARTA TIMUR',
'JAKARTA UTARA',
'JAKARTA',
'JAMBI',
'JATENG',
'JAWA TENGAH',
'JAYAPURA',
'JEMBER',
'JEPARA',
'JOMBANG',
'KAB ACEH',
'KAB BANYUMAS',
'KAB BLORA',
'KAB BOYOLALI',
'KAB BREBES',
'KAB CIREBON',
'KAB DEMAK',
'KAB GEMARANG',
'KAB GROBOGAN',
'KAB GUNUNGKIDUL',
'KAB JEPARA',
'KAB JOMBANG',
'KAB KEBUMEN',
'KAB KENDAL',
'KAB KLATEN',
'KAB KUDUS',
'KAB KUNINGAN',
'KAB LAHAT',
'KAB LAMPUNG SELATAN',
'KAB MAGELANG',
'KAB MUBA',
'KAB NGAWI',
'KAB PATI',
'KAB PEMALANG',
'KAB PURWOREJO',
'KAB SALATIGA',
'KAB SEMARANG',
'KAB SERANG',
'KAB SRAGEN',
'KAB SUKOHARJO',
'KAB TASIKMALAYA',
'KAB TEGAL',
'KAB TEMANGGUNG',
'KAB WONOGIRI',
'KABUPATEN BATANG',
'KABUPATEN BOYOLALI',
'KABUPATEN CIAMIS',
'KABUPATEN DEMAK',
'KABUPATEN GROBOGAN',
'KABUPATEN KARANGANYAR',
'KABUPATEN KENDAL',
'KABUPATEN KLATEN',
'KABUPATEN KUDUS',
'KABUPATEN PEKALONGAN',
'KABUPATEN PEMALANG',
'KABUPATEN PONOROGO',
'KABUPATEN SEMARANG',
'KABUPATEN TEMANGGUNG',
'KAJEN',
'KALIBEBER',
'KALIMANTAN BARAT',
'KALIMANTAN',
'KAMPAR',
'KAMPUNG BARU',
'KAPUAS',
'KARANG ENDAH',
'KARANG SARI',
'KARANGANYAR',
'KARANGMANGU',
'KARAWANG',
'KARTASURA',
'KARYA BAKTI',
'KASIMAN',
'KEBUMEN',
'KEC GUNUNGPATI',
'KEDABU RAPAT',
'KEDIRI',
'KENDAL',
'KENDARI',
'KEPENUHAN BARU',
'KERON',
'KETAPANG',
'KISARAN',
'KLAMPOK',
'KLATEN',
'KODYA SEMARANG',
'KOENDRAFO',
'KOLAKA',
'KOREA',
'KOTA BANDUNG',
'KOTA BANGUN III',
'KOTA BARU',
'KOTA BATAM',
'KOTA BEKASI',
'KOTA JAKARTA SELATAN',
'KOTA MADIUN',
'KOTA MAGELANG',
'KOTA PEKALONGAN',
'KOTA SALATIGA',
'KOTA SEMARANG',
'KOTA SURAKARTA',
'KOTA TANGERANG SELATAN',
'KOTA WARINGIN TIMUR',
'KOTABARU',
'KOTABUMI',
'KOTAWARINGIN BARAT',
'KOTAWARINGIN TIMUR',
'KRACAK',
'KROYA',
'KRUI',
'KUALA KAPUAS',
'KUALA SIMPANG',
'KUBANG NAN DUO',
'KUDUS',
'KULON PROGO',
'KULONPROGO',
'KUNINGAN',
'KUPANG',
'KUTAI KARTANEGARA',
'LABUHAN BATIN',
'LABUHANBATU',
'LADANG PANJANG',
'LAKELAND',
'LAMANDAU',
'LAMONGAN',
'LAMPUNG BARAT',
'LAMPUNG SELATAN',
'LAMPUNG TENGAH',
'LAMPUNG UTARA',
'LAMPUNG',
'Langkat',
'LARANTUKA',
'LAWE BERINGIN',
'LAWE PETANDUK',
'LEBAK',
'LEMPUYANG BANDAR',
'LINGGA',
'LOMBOK',
'LUBUK ALUNG',
'LUBUK BANJAR',
'LUBUK LINGGAU',
'LUMAJANG',
'LUWUK',
'MADIUN',
'MADURA',
'MAGELANG',
'MAGETAN',
'MAHAKAM ULU',
'MAJALENGKA',
'MAKASSAR',
'MAKKAH AL - MUKARRAMAH',
'MALANG',
'MALAYSIA',
'MALUKU TENGAH',
'MANADO',
'MANNA',
'MANOKWARI',
'MARGA BAKTI',
'MARGO BHAKTI',
'MARTEBING',
'MATARAM',
'MEDAN',
'MEMPAWAH',
'MERAUKE',
'METRO',
'MEUREUDU',
'MOJOKERTO',
'MOROTAI',
'MUARA BUNGO',
'MUARA ENIM',
'MULYA AGUNG',
'MUNCANG',
'MUSI BANYUASIN',
'MUSI RAWAS',
'NABIRE',
'NAINGGOLAN',
'NEGERI JEMANTEN',
'NGANJUK',
'NGAWI',
'NIAS',
'OGAN ILIR',
'OGAN KOMERING ULU',
'OKI',
'OKU TIMUR',
'PACITAN',
'PADANG KUNIK',
'PADANG PANJANG',
'PADANG PARIAMAN',
'PADANG',
'PAGALARAM',
'PAGAR ALAM',
'PAJARESUK',
'PALANGKA RAYA',
'PALEMBANG',
'PALOPO',
'PALU',
'PAMEKASAN',
'PANDEGLANG',
'PANGKAL PINANG',
'Pangkalan Bun',
'PANGKALAN KERINCI',
'PANONGAN',
'PAPUA',
'PARAPAT',
'PARE PARE',
'PARE',
'PARIAMAN',
'PASAMAN',
'PASER',
'PASURUAN',
'PATI',
'PEKALONGAN',
'PEKANBARU',
'PELAIHARI',
'PELALAWAN',
'PELANG',
'PELEM',
'PEMALANG',
'PEMATANG SIANTAR',
'PENDOPO',
'PINABETENGAN',
'PKL BRANDAN',
'PONOROGO',
'PONTIANAK',
'PRABUMULIH',
'PRAMBANAN',
'PRIANGAN',
'PROBOLINGGO',
'PULAU ARO',
'PUNGGELAN',
'PURBALINGGA',
'PURBOLINGGO',
'PURWAKARTA',
'PURWODADI',
'PURWOKERTO',
'PURWOREJO',
'RAJABASA',
'RAMA UTAMA',
'RANGKASBITUNG',
'RANTAU JAYA ILIR',
'RANTAU PRAPAT',
'REMBANG',
'RIMBO BUJANG',
'ROKAN HULU',
'RUMBIA',
'SABBANG',
'SALATIGA',
'SAMARINDA',
'SAMBAS',
'SAMOSIR',
'SAMPANG',
'SAMPIT',
'SANDANA',
'SANGATTA',
'SANGIR',
'SARANG',
'SAROLANGUN',
'SAWAHLUNTO',
'SAWANGAN',
'SAWIT SEBERANG',
'SELANGOR MALAYSIA',
'SELAT PANJANG',
'SELINGSING',
'SEMARANG',
'SEMUNDAM',
'SENTANI',
'SEPUTIH RAMAN ',
'SERANG',
'SERANGGAM',
'SERUNAI',
'SERUPA INDAH',
'SERUYAN',
'SIBOLGA',
'SIDO MAKMUR',
'SIDOARJO',
'SIDODADI',
'SIDOHARJO',
'SIDOMUKTI',
'SIDOMULYO',
'SIJUNJUNG',
'SILONGOK',
'SIMALUNGUN',
'SINGKAWANG',
'SIPAKU',
'SIRI SORI',
'SISARAHILI',
'SITUBONDO',
'SLAWI',
'SLEMAN',
'SOLO',
'SOLOK SELATAN',
'SOLOK',
'SORONG',
'SRAGEN',
'SRI LANKA',
'STABAT',
'SUBANG',
'SUKABUMI',
'SUKAKARYA',
'SUKARAJA',
'SUKOHARJO',
'SUMATRA',
'SUMBUL',
'SUMEDANG',
'SUMOGAWE',
'SUMUB LOR',
'SUNGAI BAHAR',
'SUNGAI LEBUNG',
'SUNGAI LIAT',
'SUNGAI PANTAI',
'SUNGAI PIMPING',
'SUNGAI PINANG',
'SUNGAI PINYUH',
'SUNGAI SAHUT',
'SURABAYA',
'SURAKARTA',
'SURUH',
'TABALONG',
'TALANG JAWA',
'TAMAN ASRI',
'TANAH DATAR',
'TANAH HITAM',
'TANAH LAUT',
'TANGERANG SELATAN',
'TANGERANG',
'TANGGAMUS',
'TANJUNG ENIM',
'TANJUNG JABUNG BARAT',
'TANJUNG KARANG',
'TANJUNG LUBUK',
'TANJUNG MULAK',
'TANJUNG PANDAN',
'TANJUNG PINANG',
'TAPANULI SELATAN',
'TAPANULI UTARA',
'TAPANULI',
'TARUTUNG',
'TASIKMALAYA',
'TEBO',
'TEGAL',
'TELUK BELITUNG',
'TELUK KAYU PUTIH',
'TEMANGGUNG',
'TEMBILAHAN',
'TENGARAN',
'TERNATE',
'TEROMBONG SARI',
'TETEHOSI',
'TEXAS',
'TIMIKA',
'TIMOR TIMUR',
'TINOMBO',
'TOMOK',
'TRENGGALEK',
'TRIMULYO',
'TUBAN',
'TULANG BAWANG',
'TULUNG AGUNG',
'TULUNGAGUNG',
'UJUNG PANDANG',
'UNGARAN',
'WAY KANAN',
'WAY TUBA',
'WELERI',
'WONOBOYO',
'WONOGIRI',
'WONOSARI',
'WONOSOBO',
'WONOSOCO',
'WONOSORO',
'YEH SUMBUL',
'YOGYAKARTA',
'YUKUM JAYA',
]

# %%
kota_indonesia = kota_indonesia + new_kota

# %%
df_req = df.loc[:, ['KK_NO', 'NIK', 'CUSTNAME', 'JENIS_KELAMIN','TANGGAL_LAHIR','TEMPAT_LAHIR']]
df_req['KK_NO'] = df_req['KK_NO'].map(str)
df_req['NIK'] = df_req['NIK'].map(str)
df_req['TANGGAL_LAHIR'] = pd.to_datetime(df_req['TANGGAL_LAHIR'], format="%d/%m/%Y", errors='coerce')

# %%
def is_valid_tempat_lahir(tempat_lahir):
  return tempat_lahir.upper() in kota_indonesia

# %%
def clean_data(raw_df):
    # Define criteria for clean data
    def is_valid_kk_no(kk_no):
        return isinstance(kk_no, str) and kk_no.isdigit() and len(kk_no) == 16 and kk_no[-4:] != '0000'

    def is_valid_nik(nik):
        return isinstance(nik, str) and nik.isdigit() and len(nik) == 16 and nik[-4:] != '0000'

    def is_valid_custname(custname):
        # return isinstance(custname, str) and bool(re.match("^[A-Za-z ]*$", custname))
        return isinstance(custname, str) and not any(c.isdigit() for c in custname)

    def is_valid_jenis_kelamin(jenis_kelamin):
        return jenis_kelamin in ['LAKI-LAKI','LAKI - LAKI','LAKI LAKI', 'PEREMPUAN']

    def is_valid_tempat_lahir(tempat_lahir):
        return isinstance(tempat_lahir, str) and tempat_lahir.upper() in kota_indonesia
        # return tempat_lahir in kota_indonesia

    def is_valid_date(date_str):
        if isinstance(date_str, str):
            try:
                date_obj = datetime.strptime(date_str, '%d/%m/%Y')
                if date_obj.date() <= datetime.today().date():
                    return True
                else:
                    return False
            except ValueError:
                return False
        elif isinstance(date_str, pd.Timestamp):
            if date_str.date() <= datetime.today().date():
                return True
            else:
                return False
        else:
            return False

    # Initialize the Check_Desc column with empty strings
    raw_df['Check_Desc'] = ''

    # Apply criteria to filter clean data
    valid_kk_no = raw_df['KK_NO'].apply(is_valid_kk_no)
    valid_nik = raw_df['NIK'].apply(is_valid_nik)
    valid_custname = raw_df['CUSTNAME'].apply(is_valid_custname)
    valid_jenis_kelamin = raw_df['JENIS_KELAMIN'].apply(is_valid_jenis_kelamin)
    valid_tempat_lahir = raw_df['TEMPAT_LAHIR'].apply(is_valid_tempat_lahir)
    valid_tanggal_lahir = raw_df['TANGGAL_LAHIR'].apply(is_valid_date)


    clean_df = raw_df[valid_kk_no & valid_nik & valid_custname & valid_jenis_kelamin & valid_tempat_lahir & valid_tanggal_lahir]

    # Identify issues in the data
    raw_df.loc[~valid_kk_no, 'Check_Desc'] += raw_df.loc[~valid_kk_no, 'KK_NO'].apply(
        lambda x: f'Invalid KK_NO (length: {len(str(x))}, digits only: {str(x).isdigit()}, last_digits: {x[-4:]}); '
    )
    raw_df.loc[~valid_nik, 'Check_Desc'] += raw_df.loc[~valid_nik, 'NIK'].apply(
        lambda x: f'Invalid NIK (length: {len(str(x))}, digits only: {str(x).isdigit()}, last_digits: {x[-4:]}); '
    )
    raw_df.loc[~valid_custname, 'Check_Desc'] += raw_df.loc[~valid_custname, 'CUSTNAME'].apply(
        lambda x: f'Invalid CUSTNAME (contains special characters or digits: {x}); '
    )
    raw_df.loc[~valid_jenis_kelamin, 'Check_Desc'] += raw_df.loc[~valid_jenis_kelamin, 'JENIS_KELAMIN'].apply(
        lambda x: f'Invalid JENIS_KELAMIN (value: {x}); '
    )
    raw_df.loc[~valid_tempat_lahir, 'Check_Desc'] += raw_df.loc[~valid_tempat_lahir, 'TEMPAT_LAHIR'].apply(
        lambda x: f'Invalid TEMPAT_LAHIR (value: {str(x)}); '
    )
    raw_df.loc[~valid_tanggal_lahir, 'Check_Desc'] += raw_df.loc[~valid_tanggal_lahir, 'TANGGAL_LAHIR'].apply(
        lambda x: f'Invalid TANGGAL_LAHIR (value: {str(x)}, expected format DD/MM/YYYY); '
    )
    # All other rows are considered messy data
    messy_df = raw_df[raw_df['Check_Desc'] != '']

    # Remove the Check_Desc column from the clean_df
    clean_df = clean_df.drop(columns=['Check_Desc'])

    return messy_df, clean_df

# %%
# Use the function to clean the data
messy_df, clean_df = clean_data(df_req)

# Display the results
print("Messy DataFrame:")
messy_df
# Out:
# Messy DataFrame:
#                   KK_NO               NIK                  CUSTNAME  \
# 55      332711905200019  3375020802790000                   SODIKIN
# 56      332711905200019  3327135107790000               MUHIDAYATIS
# 57      332711905200019  3327130303010000            HABAN ABDULLAH
# 58      332711905200019  3327136605130000             NADA ROMANTIS
# 60     3327103001070008  3327105907700003                   JUNARTI
# ...                 ...               ...                       ...
# 87917  3327131512150000  3327131812200000      BISMA SATRIA MAYESHA
# 87918  3327131512150000  3327135210150000      ARSYFA AQILA HANANIA
# 87919  3327131512150000  3327136103910000                   SUSANTI
# 87920  3212132207220000  3327102901960060          ARIZQI RAMADHANI
# 87921  3212132207220000  3212137004220000  SALWA QAIREEN RAHMADHANI
#
#       JENIS_KELAMIN TANGGAL_LAHIR TEMPAT_LAHIR  \
# 55        LAKI-LAKI    1979-02-08     PEMALANG
# 56        PEREMPUAN    1979-07-10     PEMALANG
# 57        LAKI-LAKI    2001-03-13     PEMALANG
# 58        PEREMPUAN    2013-05-26     PEMALANG
# 60        PEREMPUAN    1970-07-10     PEMALANO
# ...             ...           ...          ...
# 87917     Laki-Laki    2020-12-18     PEMALANG
# 87918     Perempuan    2015-10-12     PEMALANG
# 87919     Perempuan    1991-03-21     PEMALANG
# 87920     Laki-Laki           NaT     PEMALANG
# 87921     Perempuan    2022-04-20    INDRAMAYU
#
#                                               Check_Desc
# 55     Invalid KK_NO (length: 15, digits only: True, ...
# 56     Invalid KK_NO (length: 15, digits only: True, ...
# 57     Invalid KK_NO (length: 15, digits only: True, ...
# 58     Invalid KK_NO (length: 15, digits only: True, ...
# 60              Invalid TEMPAT_LAHIR (value: PEMALANO);
# ...                                                  ...
# 87917  Invalid KK_NO (length: 16, digits only: True, ...
# 87918  Invalid KK_NO (length: 16, digits only: True, ...
# 87919  Invalid KK_NO (length: 16, digits only: True, ...
# 87920  Invalid KK_NO (length: 16, digits only: True, ...
# 87921  Invalid KK_NO (length: 16, digits only: True, ...
#
# [65020 rows x 7 columns]

# %%
err_places = list(messy_df['TEMPAT_LAHIR'].unique())
err_places
# Out:
# ['PEMALANG',
#  'PEMALANO',
#  'FEMALANO',
#  'FEMALANG',
#  'BALAPULANG',
#  'PEKALONGAN',
#  nan,
#  'LANGGAN',
#  'ISLAM',
#  'FESALANG',
#  'UNITED PENALAND',
#  'JANANTA',
#  'PEMALANIA',
#  'CARD LAVE FEMALAND',
#  'SMARTA',
#  'PRENTIAN JAUFTA',
#  'TEGAL',
#  'KEBUMEN',
#  'JABUNG',
#  'SRAGEN',
#  '--------',
#  'SEMARANG',
#  'KLATEN',
#  'CIANJUR',
#  'CILACAP',
#  'KENDAL',
#  'NGANJUK',
#  'JAKARTA',
#  'PAMALAND',
#  '-',
#  'PENALDHOAN',
#  'PRIANGAN',
#  'BALUNGAN',
#  'TANGERANG',
#  'GROBOGAN',
#  'PEMALANC',
#  'WONOSOBO',
#  'CHICAGO',
#  'MAGETAN',
#  'MAGELANG',
#  'DEMAK',
#  'BANYUMAS',
#  'NGAW',
#  'IMAGINARY CITY',
#  'BOGOR',
#  'HUTANHARU',
#  'PONTIANAK',
#  'TANMPEKEBUW',
#  'TAMAL',
#  'MADIUN',
#  'MAJALENGKA',
#  'SANGIR',
#  'MANADO',
#  'CIREBON',
#  'BREBES',
#  'PEMALAN',
#  'PEKALORIGAN',
#  'HOME',
#  'TUNK',
#  'AALLANT',
#  'PERARLAND',
#  'PENALAND',
#  'FEMALAND',
#  'PANDEGLANG',
#  'SORONG',
#  'BEKASI',
#  'PIMILAND',
#  'TESAL',
#  'TESTA',
#  'LASSAR',
#  'TAMKT',
#  'SURABAYA',
#  'BOJONEGORO',
#  'SERANG',
#  'REMBANG',
#  'KAB PEMALANG',
#  'LEBAN',
#  'LAMPUNG',
#  'BANGKALAN',
#  'BANJARNEGARA',
#  'INDRAMAYU',
#  'KARANGANYAR',
#  'Banjarnegara',
#  'MEMPAWAH',
#  'REMALANG',
#  'SIMBAR',
#  'JOMBANG',
#  'SUKABUMI',
#  'PEVALAND',
#  'KOMALAND',
#  'PEMALAND',
#  'CIAMIS',
#  'SAMARINDA',
#  'SLEMAN',
#  'JEPARA',
#  'KEDIRI',
#  'PALEMBANG',
#  'TIMIKA',
#  'GRESIK',
#  'SCHONGBATA',
#  'PURWAKARTA',
#  'SUBANG',
#  'BLORA',
#  'BATANG',
#  'PURBALINGGA',
#  'PURWODADI',
#  'BANDUNG',
#  'KABUPATEN SUKOHARJO',
#  'WONOGIRI',
#  'TASIKMALAYA',
#  'NOAW',
#  'CILEGON',
#  'ANOUTA',
#  'PEMALAO',
#  'NGAWI',
#  'FEWALANCE',
#  'TAMA SOGEDERAJA',
#  'FEMALANCE',
#  'FEWALANO',
#  'POLMAS',
#  'TAMAN',
#  'TANGER',
#  'PURWOKERTO',
#  'YOGYAKARTA',
#  'AMPEL',
#  'JEGALSARI',
#  'TANJUNGPINANG',
#  'TEDAL',
#  'KABUPATEN PEKALONGAN',
#  'KOTA PEKALONGAN',
#  'MENDURLIS',
#  'TUBAN',
#  ' I',
#  'PIMNANG',
#  'POHALANO',
#  'BANTUL',
#  'ILAN',
#  'BOYOLALI',
#  'BANTEN',
#  'CIAM',
#  'MEMALAND',
#  'PEMALANCE',
#  'KULONPROGO',
#  'KERUMEN',
#  'ALAM',
#  'FUMALAND',
#  'BANJANEGARA',
#  'INDRAGRUHULU',
#  'FORALAND',
#  'HOWHLAND',
#  'PLACE  I',
#  'PUNCROGO',
#  'LEBAK',
#  'GLATSOUS',
#  'PERWIRA',
#  'PERIOLANE',
#  'KANDIS',
#  'COMAL',
#  'KUNINGAN',
#  'MOJOKERTO',
#  'TOKING',
#  'TOMATA',
#  'GWANTA',
#  'DEMAX',
#  'ACEH',
#  'WELER',
#  'BEKAS',
#  'KABUMEN',
#  'SOMEDERAJAY',
#  'TEMANGGUNG',
#  'CILACAP TIMUR',
#  'TULUNGAGUNG',
#  'REMDANG',
#  'KAB TEGAL',
#  'INDIA',
#  'KULON PROGO',
#  'SOLO',
#  'PEMALING',
#  'PENDLING',
#  'BANDAR LAMPUNG',
#  'JAKARYA',
#  'KARAWANG',
#  'FERELAND',
#  'FIMALAND',
#  'FUMLAND',
#  'TANJUNG LUBUK',
#  'BAYUNG LENCIR',
#  'TAMEDERAJAY',
#  'SAMAT',
#  'POLLUTION',
#  'PIKALONGAN',
#  'BANTAL',
#  'SUDANG',
#  'WRADINASTA',
#  'REV',
#  'TELANA',
#  'MEDAN',
#  '< I>',
#  'PURWOREJO',
#  'PEMATANG SIANTAR',
#  'SELINSING',
#  '?-',
#  'KASIS PAG',
#  'MENOURUS',
#  'MERTO LAMPUNG',
#  'LAMPUNG UTARA',
#  'KOTABUMI',
#  'PRIVALARD',
#  'PRIVALAND',
#  'GLAWT',
#  'WONSOSOBO',
#  'PERMALANO',
#  'SOMEDERAJAT',
#  'MALUKU TENGAH',
#  'SURAKARTA',
#  'SUKOHARJO',
#  'TAMBET',
#  'HILLAND',
#  'TIDAK DIKETAHUI',
#  'UZUNG PANDANG',
#  'KAPIL',
#  'INDRAGIRIHULU',
#  'LAKELAND',
#  'CASHYER',
#  'PEKANBARU',
#  'LABULCANI',
#  'MATRAMAN',
#  'PENALANG',
#  'DISKA SMARTS',
#  'PANGKAL PINANG',
#  'PROMACANO',
#  'FESIVALANO',
#  'TROUALANG',
#  'SAMERYZ',
#  'PENALONESS',
#  'PEKALOMIAN',
#  'KABUPATEN',
#  'MOMALAND',
#  'PEACLAND',
#  'PATI',
#  'CARLING',
#  'BANARNEGARA',
#  'BANIARNEGARA',
#  'UNKNNOW PEKANBARU',
#  'PEKALONGA',
#  'NAINGGOLAN',
#  'BUNTU MAULI',
#  'BERAU',
#  'ACEH BESAR',
#  'PASURUAN',
#  'FLAM',
#  'PALU',
#  'TAMU',
#  'WARU',
#  'FEMALANC',
#  'PEKALOHOAN',
#  'FEMALMIS',
#  'TAMAS',
#  'TARK',
#  'PELUTAN',
#  'MADURA',
#  'CIREROL',
#  'PENALING',
#  'FINLAND',
#  'ALANG',
#  'KARANG SARI',
#  'BANJAR NEGARA',
#  'KOTA BANGUN',
#  'KUTAI KARTANEGARA',
#  'MAILE',
#  'CHANG',
#  'TANGGER',
#  'PENDALANG',
#  'MINISTRY TOMICSAN',
#  'PEMKLAND',
#  'INSURANCE',
#  'MEDIUN',
#  'KENON',
#  'FEMALANS',
#  'SLAWI',
#  'TOAK TAHL',
#  'GLASS',
#  'NUM',
#  'LANNLAND',
#  'MARALAND',
#  'KOTA PEMALANG',
#  'KOTA TANGERANG',
#  'GUNUNG KIDUL',
#  'PEMALANGO',
#  'PACITAN',
#  'SAMALAKO',
#  'BINJAI',
#  'HEMALAND',
#  'MALANG',
#  'UNGARAN',
#  'BANJARAN',
#  'FISHLAND',
#  'SANGGAU KULOR',
#  'PEMALAM',
#  'CILACAR',
#  'KENDA',
#  'POWSLAND',
#  'PRAMBANAN',
#  'LANG-AND PEDALANC',
#  'TIDAK TAHU',
#  'PEVILLAND',
#  'REVALAND',
#  'CAKILLAN',
#  'CALIFORNIA',
#  'PETARUKAN',
#  'AMBON',
#  'SURUH',
#  'SILLEMAN',
#  'BATANIC',
#  'GONDANG',
#  'DEPOK',
#  'MENOURIA',
#  'LANGGAM',
#  'SIDOARJO',
#  'NEWARK',
#  'KOTA ABC',
#  'LUMAJANG',
#  'KALIMAS',
#  'PEALANG',
#  'PRACTICA',
#  'GARUT',
#  'MINCANG',
#  'HEMALANG',
#  'FEVALAND',
#  'TEMALAND',
#  'SIDGARJO',
#  'PONOROGO',
#  'REPUBLIC OF INDONESIA',
#  'KEPALIT KENAGE',
#  'SUKLIWON',
#  'PEMACANG',
#  'PEIMALANG',
#  'KAB SEMARANG',
#  'TERMINALS',
#  'SALATIGA',
#  'KUDUS',
#  'KABUPATEN SEMARANG',
#  'DEMAS',
#  'KAB DEMARANO',
#  'KAB GEMARANO',
#  'PURPORED',
#  'KAB. SEMARANG',
#  'BANYUASIN',
#  'TIDAK DITEMUKAN',
#  'AMBARAWA',
#  'PELALAWAN',
#  'LUBUKLINGGAU',
#  'KAB.SEMARANG',
#  'DURI',
#  'PADANG',
#  'KABUPATEN BEHARANO',
#  'KARANG ANYAR',
#  'SAMPANG',
#  'PONCROGO',
#  'UTHA',
#  'MUKDHANJO',
#  'HURAKANTA',
#  'BANYUWANGI',
#  'MELIAU',
#  'KAR.SEMARANG',
#  'KAD DEMARMIN',
#  'MADELANG',
#  'ASSUMENT',
#  'SEM',
#  'KAR SEMARANG',
#  'DEMARINO',
#  'KAR',
#  'KABUPATEN REMARANG',
#  'BATANGMATA',
#  'MAKASSAR',
#  'KAB.MAGETAN',
#  'PURWODADE',
#  'BOYO ALI',
#  'KAB SEMARANGE',
#  'KAB GENARANI',
#  'KAB SEMBRAN',
#  'KABUPATEN BOYOLALI',
#  'NANGA PINOH',
#  'CIMAHI',
#  'KAB BOYOLALI',
#  'NOTORALI',
#  'MARTEBING',
#  'PROBOLINGGO',
#  'KAR SUMMANO',
#  'KAB GROBOGAN',
#  'BANDA ACEH',
#  'KAWASAN',
#  'TANDUK',
#  'JAWA TENGAH',
#  'DEMAN',
#  'KAR GEM ARANO',
#  'KAB SERANG',
#  'CARHLAND',
#  'BOYOCAL',
#  'BOYOLAU',
#  'BOYOLAL',
#  'KAB. GEMARANG',
#  'KABUPATEN PONOROGO',
#  'JLONPROGO',
#  'TANGERANG SELATAN',
#  'KEBUHEN',
#  'BUKABUM',
#  'BOYO',
#  'BOYOL',
#  'BOYOU',
#  'BRONGKOL',
#  'PENAWANGAN',
#  'SEMARANO',
#  'KAB. SMG',
#  'BUKIT INGGI',
#  'BRAGEN',
#  'PANGKALAN BUN',
#  'P.ALAM',
#  'SUNGAI SAHUT',
#  'MUARA BUNGO',
#  'MUARA RUNGO',
#  'BADUNG',
#  'KAD SEMARANO',
#  'BUMATRA',
#  'KAB.GEMARANG',
#  'KABUPATEN BLORA',
#  'KAB DESAAREANIS',
#  'KAB SEMAINING',
#  'SAMARANG',
#  'PALANGKA RAYA',
#  'LANGKLAND',
#  'SONTAL',
#  'BANYUBIRU',
#  'KAB. BOYOLALI',
#  'KAB. SEMANANG',
#  'BOYOLADI',
#  'DEMARAS',
#  'UNGAHAN',
#  -8,
#  'KUBANG NAN DUO',
#  'KAB, SEMARANG',
#  'KABUPATEN MAGELANG',
#  'MUARA ENIM',
#  'WONGSORO',
#  'GUNAWAN',
#  'ROVOLALI',
#  'KABUPATEN WAINGIN TIMUR',
#  'CLACAR',
#  'CANTUME',
#  'PURBALINOGA',
#  'SOLOK',
#  'KENDARI',
#  'TANJUNG ENM',
#  'NOTICALL',
#  'REMSAND',
#  'IA',
#  'CLUB',
#  'JAKARTA BARAT',
#  'PERAL LONGAN',
#  'HANJAMICARA',
#  'TARUTUNG',
#  'HORISAN',
#  'WONOSORO',
#  'PAGI',
#  'KARILANT',
#  'BANJARNAGARA',
#  'SAMBAS',
#  'BANJARHEGARA',
#  'GUNUNGKIDUL',
#  'BANJARNEARA',
#  'DENPASAR',
#  'SANGARMEGARA',
#  'INDRAGIRI HILIR',
#  'SUMINGAN',
#  'PAT',
#  'UNLAN',
#  'SHU/RNGGARA',
#  'WONOSOSO',
#  'SANJARNEGARA',
#  'HONDARD',
#  'LAMONGAN',
#  'WONDSOBO',
#  'LAMPUNG SELATAN',
#  'SANGGAU',
#  'WONOGOBO',
#  'BAIJIAPHEGARA',
#  'WONOBOBO',
#  'TABALONG',
#  'MATARAM',
#  'SEMARANC',
#  'FRANCISCO',
#  'RONGSONG',
#  'WUNOSOBO',
#  'PURWUKERTO',
#  'BO',
#  'TEMANGGOUNG',
#  'PUWOKERTO',
#  'SUMATERA',
#  'MAKYAN',
#  'WORKSTORO',
#  'WONOSCHO',
#  'LAALLAND',
#  'KOCOLAN',
#  'BONDOWOSO',
#  'BANJARNOGARA',
#  'DEMARANG',
#  'SLAMET',
#  'WONDOSOBO',
#  'GREBES',
#  'BANJAR',
#  'WENOSOBO',
#  'MERAUKE',
#  'BANJARNESARA',
#  'BANJARMEGAMA',
#  'BANJARKEDANA',
#  '<INPUT TEMPAT LAHIR HERE>',
#  'BENGKULU',
#  'SANJARMENGGALAM',
#  'MAJAPHESIAN',
#  'KOLAKA',
#  'PARE-PARE',
#  'SERUYAN',
#  'LANGKAT',
#  'NAGELAND',
#  'BIKA',
#  'PAGANO',
#  'PERCUPUM',
#  'TOWNI',
#  'KAMPAR',
#  'WORDSONG',
#  'WONDE',
#  'WONDSOMO',
#  'BAILIPREGARA',
#  'HONORDED',
#  'KEPENUHAN BARU',
#  'BANUARNEGARA',
#  'MACELANO',
#  'BATANGHARI',
#  'WONDACHE',
#  'UMBAK ITEM',
#  'CREAM STUNITIME',
#  'KARTAMAN',
#  'SUBM',
#  'TUMANG',
#  'YORK',
#  'WONOSOHO',
#  'KABUPATEN WONOSOBO',
#  'BELINYU',
#  'SUNGAI BAHAR',
#  'JAMBI',
#  'JAKARTA PUSAT',
#  'MEDERAJAT',
#  'SEE GONCHO',
#  'WONDERS',
#  'CLAMIS',
#  'BLAWE',
#  'TONKTAN',
#  'CANDY',
#  'PRINGAMBA',
#  'ANSLINE',
#  'INLAND',
#  'MEGAN',
#  'TAMPFAKERIN',
#  'BATAM',
#  'CIKARANG',
#  'WONDSCIBO',
#  'KALIMANTAN',
#  'BANJAJENEGARA',
#  'WONOBOYO',
#  'TEXAS',
#  'NONSORD',
#  'YASAAN',
#  'SUMEDANG',
#  'BANGGAI',
#  'WONDSORO',
#  'MAHAKAM ULU',
#  'WONDEONG',
#  'WONDSOGO',
#  'BANJARHENARA',
#  'MACANG',
#  'BANJARNETARA',
#  'BANJARNEJARA',
#  'BANJARNECARA',
#  'BANJARNEYARA',
#  'BANJARNELARA',
#  'VI',
#  'KHUSNE',
#  'KOTA MAGELANG',
#  'SUKARN',
#  'WICKOSIBO',
#  'INDRAPURA',
#  'PEGAJAHAN',
#  'KEATEN',
#  'PURWODAD',
#  'KEDIN',
#  'EXAMPLE CITY',
#  'BANJAREGARA',
#  'BANJARMEGARA',
#  'WARINGIN TIMUR',
#  'WONGSOB',
#  'GANJARNGARA',
#  'WONDOIR',
#  'SIPAKU',
#  'GULON PROGO',
#  '—— INVALID ——',
#  'SAMPIT',
#  'CIAME',
#  'WONOBORO',
#  'JAKARTA TIMUR',
#  datetime.datetime(1968, 5, 10, 0, 0),
#  'LEKSANA',
#  'TAPA UTARA',
#  'PETIR',
#  'IDLAN',
#  'FIGA',
#  'MURBALINOGA',
#  'TANJUNG KARANG',
#  'SILONGOK',
#  'BLITAR',
#  'SANJARNEGAHA',
#  'LABUHAN BATIN',
#  'WONGSOBO',
#  'PEMALANGAN',
#  'BREDES',
#  'BALIKPAPAN',
#  'SOYCAL',
#  'HOMELAND',
#  'TEMANOGUNG',
#  'KAB SEVARANO',
#  'BOYOLALO',
#  'WUNG PANDANG',
#  'KAB CEMMING',
#  'KAILSEMARAND',
#  'KAR SEMARAND',
#  'SEMARABIO',
#  'COYOLAL',
#  'KAB DEMARANG',
#  'KAB REMBANG',
#  'SUMARANG',
#  'PERBAUNGAN',
#  'BATAN',
#  'NEMBANG',
#  'KAB STANDANG',
#  'BOYOLATE',
#  'LANDFORD',
#  'LAN',
#  'VONOSUBO',
#  'BURAKARTA',
#  'KAF SEHARANG',
#  'SCYOUR',
#  'BOYOUND',
#  'SALATISA',
#  'SALATICA',
#  'BCRA',
#  'DEMARANO',
#  'KAB HEMARANO',
#  'KAB SEMAHANG',
#  'KAR. SEMARANG',
#  'POLIMPHAN HOMARAND',
#  'PCHEMPLAN SEMARANO',
#  'TELUK KAYU PUTH',
#  'MUARADUA',
#  'KAB SEM ANG',
#  'KAB SEM/ ANG',
#  'BOLON',
#  'ANY',
#  'GEMOLONG',
#  'BALATIGA',
#  'SALATHIA',
#  'KAB GELAARANG',
#  'KAB BATANG',
#  'BIAK SRI INDRAPURA',
#  'KAB SEMARANO',
#  'SIDANGGUNUNG',
#  'PROBOUNGGO',
#  'TIMAHANG',
#  'KAR SEMARANO',
#  'AMBARAMA',
#  'KAB.NGAWI',
#  'KAB. SEMARANG ',
#  'TOBASA',
#  'KUTA CANE',
#  'SIMANAUNGUS',
#  'BOYCLASE',
#  'BANDAR',
#  'KAB TEMARANG',
#  'KAB REMARANCE',
#  'KAB. LAMONGAN',
#  'KAB. BLITAR',
#  'KAB. WONOGIRI',
#  'SOYOLAL',
#  'ALATIMA',
#  'CALABIA',
#  'CALATION',
#  'Pemalang',
#  'MARTA',
#  'RANGKAS BITUNG',
#  'PAGARALAM',
#  'TEROGET',
#  'TEMOSI',
#  'KOTA',
#  'PULL',
#  'PEKALONSAN',
#  'BREACH',
#  'PETSALANG',
#  'BLAND',
#  'PEWALANG',
#  'PANTAU',
#  'LOMBOK',
#  'PENALARIA',
#  'TETEHOSI',
#  'MANOKWARI',
#  'PERDAGANGAN',
#  'KARANDANYAR',
#  'BATIGA',
#  'BANYUWANG',
#  'GUNUNGSARI',
#  'T.BAYAN',
#  'PANDAN SURAT',
#  'KUNING GADING',
#  'MAKASAR',
#  'LEBK',
#  'GROGONGAN',
#  'LHOK SUKON',
#  'TIRTA KENCANA',
#  'BANGKA BARAT',
#  'BERASTAGI',
#  'GEDUNG NEGARA',
#  'BG.SIAPI-API',
#  'WATAMPONE',
#  'GROBOAN',
#  'ILMANGGUNG',
#  'KARANG WIJAYA',
#  'LAMONGAN, JATIM',
#  'KABUPATEN KENDAL',
#  'SEMELINANG/PERANAP',
#  'BAKAM',
#  'SIMALUNDUN',
#  'KOTA SEMARANG',
#  'BANDINI AGUNG',
#  'PENANTIAN',
#  'KABUPATEN TEGAL',
#  'KENDAL ',
#  'FIRU',
#  'LIRIK',
#  'TULUNG BAWANG',
#  'KABUPATEN PURWODADI',
#  'MADUN',
#  'TAKENG ON',
#  'KLAYTEN',
#  'PEMEKASAN',
#  'WONGDGON',
#  'KAB SEMARAN',
#  'SANGGAL',
#  'KUALA TUNGKAL',
#  'SUMENEP',
#  'KAD SEMARANG',
#  'SEKASI',
#  'TANJUNG ENIM',
#  'PRABUMULIH',
#  'KOTA BARU',
#  'TEROMBONG SARI',
#  'REMAILING',
#  'HEMAKANI',
#  'GEMARANG',
#  'KAS',
#  'KAB REMARANG',
#  'KAB. BANYUMAS',
#  'KAB. LAMPUNG',
#  'KAB GEMARANG',
#  'WONODERO',
#  'KAB NGAW',
#  'KAIL SEMARANG',
#  'SOYOLALI',
#  'SOYOUAL',
#  'SOYOUALI',
#  'SUNAKARTA',
#  'KAB. PATI',
#  'KAB-SEMARANG',
#  'KAB BEMARANG',
#  'HUM',
#  'JAYA',
#  'KAB PURWOREJO',
#  'GRAGEN',
#  'TANAH LAUT',
#  'KOTABARU',
#  'LABUHAN BATU',
#  'BOYOLAL...',
#  'LAGUE INGRETA',
#  'CHERON',
#  'KAB MAGELANG',
#  'KAB.DEMARANO',
#  'BALATICA',
#  'NOT DEFINED',
#  'TAMBAKHOYO',
#  'MADELANO',
#  'KLEPU',
#  'WISCONSIN',
#  'NOVOLAU',
#  'KAR SEMARANC',
#  'KABUPATEN BREBES',
#  'KOTA SALATIGA',
#  'KAILGEMARAND',
#  'REMBAK',
#  'BALATIBA',
#  'MUSI RAWAS',
#  'INSONETIA',
#  'KAB. DEMAK',
#  'JEMBER',
#  'FADANG',
#  'BANOLING',
#  'HANDLING',
#  'KAT LEMARANG',
#  'KAD TEMARANO',
#  'BAGAN SIAPI-API',
#  'ULAM',
#  'MOTOUNI',
#  'ILHAM',
#  'KAB SOMARANG',
#  'SHAGEN',
#  'SANING BAKAR',
#  'SANIANG BAN',
#  'ISLAND',
#  'GEMARANO',
#  'GRAGEH',
#  'FALONBANG',
#  'BOYOTALI',
#  'KAB DEMARANCE',
#  'OGAN KOMERING ILIR',
#  'KAB LONARDANS',
#  'KAB DEMARANC',
#  'CEMARANG',
#  'BOYULARI',
#  'AMELANI',
#  'KAB. SOLO',
#  'TIDAR',
#  ' ',
#  'MENGUAUS TANOGA',
#  'KAB SEHARANG',
#  'VERNINE',
#  'SURAKARIA',
#  'KARLIEMARANG',
#  'KAB KEBUMEN',
#  'SUKOHAR',
#  'TAMPAI',
#  'SENAFANG',
#  'KAB SEMAKANO',
#  'KALOM PROCO',
#  'KREATIN',
#  'WOLDON',
#  'SALATION',
#  'KAD OR MARANO',
#  'KEC',
#  'NONOGIRI',
#  'DEHARANG',
#  'CAMA SOMEDERAJA',
#  'JAYAPURA',
#  'POTOCAL',
#  'POYOKALE',
#  'DOVOLALL',
#  'NOTOLAL',
#  'ROVOLAL',
#  'MOTOLALL',
#  'HOLYOLAH',
#  'PETARAN',
#  'WONGGINI',
#  'KOREA',
#  'DALATION',
#  'KAZ ENGRAND',
#  'KAB',
#  'GREAN',
#  'KAR JAMARANO',
#  'DEAR TAKER',
#  'KAR KEMARANG',
#  'KOTA MADIUN',
#  'SURU',
#  'MADEN',
#  'FAR',
#  'PAPALIAN',
#  'SEEDLAR',
#  'WONDBOBO',
#  'SEMARKING',
#  'KAMPUNG BARU',
#  'JOGYAKARTA',
#  'KAB PATI',
#  'TRENGGALEK',
#  'GUNUNG SITOLI',
#  'TEHANGOUNG',
#  'KAH SEMARANG',
#  'KARTU KELUARGA',
#  'AKEDAGA',
#  'KAB SAYANA',
#  'AREBOA',
#  'TENTREM',
#  'TEMANANS',
#  'REMAING',
#  'TUHEMBUASI',
#  'HILIZOROILAWA',
#  'BALAPAN',
#  'KAB DEMAK',
#  'PAHAE',
#  'NADEAK',
#  'KAISE',
#  'SENOTO',
#  'BEROTO',
#  'BOYOUAL',
#  'KOYOLALI',
#  'BOYOKALI',
#  'PELEM',
#  'TALIO',
#  'PUSARANAGARA',
#  'SEMARNAG',
#  'MEMORE',
#  'GROHOGAN',
#  'PINABETENGAN',
#  'ROYCLALL',
#  'BALATION',
#  'SINOKAWANG',
#  'BANJARMASIN',
#  'PERESHFUA',
#  'BONDOWOSC',
#  'KAB SEMAS',
#  'KAB SEMING',
#  'BANDA LAMPUNG',
#  'CISAMPANG',
#  'SEMARANIC',
#  'ROYOLALI',
#  'UJUNG PANDANG',
#  'KAHYAWAH',
#  'NUR ATIK',
#  'KAB BEMARANO',
#  'TALANG JAWA',
#  'TRIVULYO',
#  'TEOLA',
#  'LEMPUYANG BANDAR',
#  'LEMPAYUNG BANDAR',
#  'LANDLAND',
#  'HUMBANG',
#  'REMBANO',
#  'AKHLAND',
#  'PREMEPHIAN',
#  'TULUNG AGUNG',
#  'KAB SUMARANO',
#  'BANTIA',
#  'GOMBONG',
#  'BENGKALIS',
#  'BUKIT TINGGI',
#  'KABUPATEN CIAMIS',
#  'KOTA BANDUNG',
#  'KOENDRAFO',
#  'KAB. SEMARANS',
#  'TIMARANO',
#  'KAD.',
#  'SEMBARANG',
#  'PETANDUK',
#  'LAWE BERINGIN',
#  'KAB  SEMARANG',
#  'TIDAK ADA',
#  '---',
#  'KERAYANG',
#  'AIR BARU',
#  'AIR BARIJ',
#  'MARATHON',
#  'BOYOLALE',
#  'KAB. SEMARAS',
#  'KAB. SEHARING',
#  'KAB. SEMARING',
#  'DEMARINA',
#  'BIMA',
#  'KA SEWARANG',
#  'RAB BRMARANG',
#  'DENA',
#  'KAULEN ANG',
#  'KAB SEN ANG',
#  'SITUBONDO',
#  'KAR S.MERARANO',
#  'LANGLARD',
#  'KAB.BOYOLALI',
#  'KAB LAMPUNG SELATAN',
#  'KAB KENDAL',
#  'WONOGR',
#  'ROYAKART',
#  'KAB REMARKARD',
#  'CARRICARE KAE LEMARANG',
#  'TANJUNG JABUNG BARAT',
#  'OGAN ILIR',
#  'ID',
#  'GLAN',
#  'TORTAN',
#  'SRADEN',
#  'BOYOLALL',
#  'BOYOUALI',
#  'SIDCHARJO',
#  'CROBOGAN',
#  'SEMANG',
#  'KAB.GROBOGAN',
#  'USUA',
#  'JEMARAN',
#  'ANAK',
#  'PRADINAS',
#  ...]

# %%
print(len(err_places))
# Out:
# 2139

# %%
print("\nClean DataFrame:")
print(clean_df)
# Out:
# Clean DataFrame:
#                   KK_NO               NIK              CUSTNAME JENIS_KELAMIN  \
# 0      3327101001080020  3327102605810001              MUKLISIN     LAKI-LAKI
# 1      3327101001080020  3327105004860025               TARMUNI     PEREMPUAN
# 2      3327101001080020  3327105405050082  LULU VENNESI SOFIANA     PEREMPUAN
# 3      3327101001080020  3327102412110007     FAUZAN AL BAIHAQI     LAKI-LAKI
# 4      3327042408170002  3326091204850007               ROBI'IN     LAKI-LAKI
# ...                 ...               ...                   ...           ...
# 83584  3327101305080030  3327105104740043                 RAMAH     PEREMPUAN
# 83585  3327101305080030  3327100507000120         WAHYU HIDAYAT     LAKI-LAKI
# 83586  3327101305080030  3327103005940060          HURTO SUGITO     LAKI-LAKI
# 83601  3327102209070180  3327106002840040                MUYATI     PEREMPUAN
# 83607  3327102601060020  3327106907830020               DARYATI     PEREMPUAN
#
#       TANGGAL_LAHIR TEMPAT_LAHIR
# 0        1981-06-20     PEMALANG
# 1        1986-04-10     PEMALANG
# 2        2005-05-14     PEMALANG
# 3        2011-12-24     PEMALANG
# 4        1985-04-12     PEMALANG
# ...             ...          ...
# 83584    1974-04-11     PEMALANG
# 83585    2000-07-05     PEMALANG
# 83586    1994-05-30     PEMALANG
# 83601    1964-02-20     PEMALANG
# 83607    1993-07-29     PEMALANG
#
# [22902 rows x 6 columns]

# %%
num_rows, num_cols = messy_df.shape
num_cols
# Out:
# 7

# %%
# Generate summary information

total_data = len(df)
messy_data = len(messy_df)
clean_data = len(clean_df)

num_rows, num_cols = messy_df.shape
len_param = num_cols - 1

invalid_kk = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid KK_NO')])
invalid_nik = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid NIK')])
invalid_name = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid CUSTNAME')])
invalid_gender = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid JENIS_KELAMIN')])
invalid_places = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid TEMPAT_LAHIR')])
invalid_date = len(messy_df[messy_df['Check_Desc'].str.contains('Invalid TANGGAL_LAHIR')])
# total_invalid = invalid_kk + invalid_nik + invalid_name + invalid_gender + invalid_places + invalid_date
# total_parameter = len(df) *  6
# total_clean = total_parameter - total_invalid
total_invalid = len(messy_df) * len_param
messy_invalid = invalid_kk + invalid_nik + invalid_name + invalid_gender + invalid_places + invalid_date
clean_invalid = total_invalid - messy_invalid

# %%
summary = {
    "Total Data": total_data,
    "Total Data %": round(total_data / total_data * 100, 2),
    "Messy Data": messy_data,
    "Messy Data %": round(messy_data / total_data * 100, 2),
    "Clean Data": clean_data,
    "Clean Data %": round(clean_data / total_data * 100, 2)
}

invalid = {
    # "Total Parameter": total_parameter,
    # "Total Parameter %": round(total_parameter / total_parameter * 100, 2),
    # "Clean Parameter": total_clean,
    # "Clean Parameter %": round(total_clean / total_parameter * 100, 2),
    # "Invalid Parameter": total_invalid,
    # "Invalid Parameter %": round(total_invalid / total_parameter * 100, 2),
    "Invalid Parameter": total_invalid,
    "Invalid Parameter %": round(total_invalid/total_invalid * 100, 2),
    "Clean Parameter": clean_invalid,
    "Clean Parameter %": round(clean_invalid/total_invalid * 100, 2),
    "Messy Parameter": messy_invalid,
    "Messy Parameter %": round(messy_invalid/total_invalid * 100, 2),
    "Invalid KK": invalid_kk,
    "Invalid KK %": round(invalid_kk / total_invalid * 100, 2),
    "Invalid NIK": invalid_nik,
    "Invalid NIK %": round(invalid_nik / total_invalid * 100, 2),
    "Invalid Name": invalid_name,
    "Invalid Name %": round(invalid_name / total_invalid * 100, 2),
    "Invalid Gender": invalid_gender,
    "Invalid Gender %": round(invalid_gender / total_invalid * 100, 2),
    "Invalid Places": invalid_places,
    "Invalid Places %": round(invalid_places / total_invalid * 100, 2),
    "Invalid Date": invalid_date,
    "Invalid Date %": round(invalid_date / total_invalid * 100, 2)

}

# %%
print(30*"-")
print(7*" ","SUMMARY INFO")
print(30*"-")
for key, value in summary.items():
    print(f"{key}: {value}")
print(30*"-")
print(7*" ","INVALID INFO")
print(30*"-")
for key, value in invalid.items():
    print(f"{key}: {value}")
print(30*"-")
# Out:
# ------------------------------
#         SUMMARY INFO
# ------------------------------
# Total Data: 87922
# Total Data %: 100.0
# Messy Data: 65020
# Messy Data %: 73.95
# Clean Data: 22902
# Clean Data %: 26.05
# ------------------------------
#         INVALID INFO
# ------------------------------
# Invalid Parameter: 390120
# Invalid Parameter %: 100.0
# Clean Parameter: 258070
# Clean Parameter %: 66.15
# Messy Parameter: 132050
# Messy Parameter %: 33.85
# Invalid KK: 25128
# Invalid KK %: 6.44
# Invalid NIK: 50252
# Invalid NIK %: 12.88
# Invalid Name: 14358
# Invalid Name %: 3.68
# Invalid Gender: 25599
# Invalid Gender %: 6.56
# Invalid Places: 7199
# Invalid Places %: 1.85
# Invalid Date: 9514
# Invalid Date %: 2.44
# ------------------------------

# %%
# Prepare summary data for Excel
summary_headers = ["Category","Total Data", "Messy Data","Clean Data","","Invalid Parameter","Clean Parameter","Messy Parameter", "Invalid KK", "Invalid NIK", "Invalid Name", "Invalid Gender", "Invalid Places", "Invalid Date"]
# summary_counts = ["Data",summary["Total Data"], summary["Messy Data"], summary["Clean Data"], invalid["Total Parameter"], invalid["Clean Parameter"], invalid["Invalid Parameter"], invalid["Invalid KK"], invalid["Invalid NIK"], invalid["Invalid Name"], invalid["Invalid Gender"], invalid["Invalid Places"], invalid["Invalid Date"]]
summary_counts = ["Data",summary["Total Data"], summary["Messy Data"], summary["Clean Data"],"", invalid["Invalid Parameter"], invalid["Clean Parameter"], invalid["Messy Parameter"], invalid["Invalid KK"], invalid["Invalid NIK"], invalid["Invalid Name"], invalid["Invalid Gender"], invalid["Invalid Places"], invalid["Invalid Date"]]
summary_percentages = ["Data (%)",summary["Total Data %"], summary["Messy Data %"], summary["Clean Data %"],"",invalid["Invalid Parameter %"], invalid["Clean Parameter %"],invalid["Messy Parameter %"], invalid["Invalid KK %"], invalid["Invalid NIK %"], invalid["Invalid Name %"], invalid["Invalid Gender %"], invalid["Invalid Places %"], invalid["Invalid Date %"]]

# %%
# !pip install xlsxwriter
writer = pd.ExcelWriter('full_result_POC_1.xlsx', engine='xlsxwriter')

messy_df.to_excel(writer, sheet_name="Messy Data")
clean_df.to_excel(writer, sheet_name="Clean Data")

summary_df = pd.DataFrame([summary_counts, summary_percentages], columns=summary_headers)
summary_df.to_excel(writer, sheet_name='Summary', index=False)

writer.close()
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.10/dist-packages (3.2.0)

# %%
end_time = time.time()
duration = end_time - start_time
print(f"Script execution time: {duration:.2f} seconds")
# Out:
# Script execution time: 203.79 seconds
